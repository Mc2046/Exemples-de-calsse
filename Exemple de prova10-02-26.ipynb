# %% [markdown]
# # **Exemple de prova** #

# %% [markdown]
# Operacions senzilles

# %%
3+2
# Out:
# 5

# %%
mesura1=25

# %%
T=mesura1/3

# %%
print(T)
# Out:
# 8.333333333333334

# %%
print(T)
print(2*T)
print(mesura1)
# Out:
# 8.333333333333334
# 16.666666666666668
# 25

# %%
llista_numeros=[1,-4,67.9]
llista_text=["hola","adeu","Angel"]

# %%
print(llista_numeros)
# Out:
# [1, -4, 67.9]

# %%
print(llista_numeros[1])
# Out:
# -4

# %% [markdown]
# llistes amb python comencen en 0

# %%
print(llista_numeros[0])
# Out:
# 1

# %%
c=llista_numeros[1]-llista_numeros[2]
print(c)
# Out:
# -71.9

# %%
d=llista_text[1]+llista_text[2]
print(d)
# Out:
# adeuAngel
