# %% [markdown]
# 17/02/2026

# %% [markdown]
# "**exemples comandes python**"

# %%
a=input("entra un numero")
# Out:
# entra un numero 4.5

# %%
b=a/3.0 #aixi donarà error #TypeError: unsupported operand type(s) for /: 'str' and 'float'
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 b=a/3.0 #aixi donarà error #TypeError: unsupported operand type(s) for /: 'str' and 'int'
#       2 print(b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
a=float(input("entra un numero")) #si volguesim treure el error kernel restart kernel and clear...
# Out:
# entra un numero 4.5

# %%
b=a/3.0
print(b)
# Out:
# 1.5
